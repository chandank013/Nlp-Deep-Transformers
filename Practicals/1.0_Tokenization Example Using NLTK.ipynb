# %%
corpus="""Hello Welcome,to Chandan's classroom.
I used to watch the entire course! to become expert in NLP.
"""

# %%
print("Original Corpus:")
print(corpus)
# Out:
# Original Corpus:
# Hello Welcome,to Chandan's classroom.
# I used to watch the entire course! to become expert in NLP.

# %%
# Tokenization
# Sentence --> paragraphs
from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome,to Chandan's classroom.
# I used to watch the entire course!
# to become expert in NLP.

# %%
# Tokenization 
# Paragraph --> words
# sentence ---> words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Chandan',
#  "'s",
#  'classroom',
#  '.',
#  'I',
#  'used',
#  'to',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Chandan', "'s", 'classroom', '.']
# ['I', 'used', 'to', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Chandan',
#  "'",
#  's',
#  'classroom',
#  '.',
#  'I',
#  'used',
#  'to',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

tokenizer=TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Chandan',
#  "'s",
#  'classroom.',
#  'I',
#  'used',
#  'to',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
